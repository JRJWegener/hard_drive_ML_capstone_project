# %% [markdown]
# import statements

# %%
import polars as pl
import pandas as pd
import datetime as dt

# %% [markdown]
# import data

# %%
import preprocessing.feature_engineering as fe

# %%
df_all = pl.read_parquet('./data/2022_data_selected.parquet')

# %%
df_faildict= fe.create_faildate_dict(df_all)

# %%
df_all.shape
# Out:
# (80357762, 37)

# %%
#df_faildates = df_all.filter(pl.col("failure") == 1)

# %%
#df_faildates = df_faildates.to_pandas()

# %%
#df_faildates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df_faildates
#
# NameError: name 'df_faildates' is not defined

# %%
creation_date=fe.create_faildate(df_all, df_faildict)

# %%
classification_target = fe.create_target_classification(creation_date)
classification_target.head()
# Out:
# shape: (5, 40)
# ┌────────┬────────────┬───────┬────────────┬─────┬────────────┬──────────┬────────────┬────────────┐
# │ date   ┆ serial_num ┆ model ┆ capacity_b ┆ ... ┆ smart_199_ ┆ faildate ┆ Time_till_ ┆ failing_in │
# │ ---    ┆ ber        ┆ ---   ┆ ytes       ┆     ┆ raw        ┆ ---      ┆ failure    ┆ 14days     │
# │ date   ┆ ---        ┆ str   ┆ ---        ┆     ┆ ---        ┆ date     ┆ ---        ┆ ---        │
# │        ┆ str        ┆       ┆ i64        ┆     ┆ i64        ┆          ┆ duration[m ┆ i32        │
# │        ┆            ┆       ┆            ┆     ┆            ┆          ┆ s]         ┆            │
# ╞════════╪════════════╪═══════╪════════════╪═════╪════════════╪══════════╪════════════╪════════════╡
# │ 2022-0 ┆ ZLW18P9K   ┆ ST140 ┆ 1400051964 ┆ ... ┆ 0          ┆ null     ┆ null       ┆ 0          │
# │ 3-11   ┆            ┆ 00NM0 ┆ 3136       ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ 01G   ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 2022-0 ┆ ZLW0EGC7   ┆ ST120 ┆ 1200013862 ┆ ... ┆ 0          ┆ null     ┆ null       ┆ 0          │
# │ 3-11   ┆            ┆ 00NM0 ┆ 5024       ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ 01G   ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 2022-0 ┆ ZA1FLE1P   ┆ ST800 ┆ 8001563222 ┆ ... ┆ 0          ┆ null     ┆ null       ┆ 0          │
# │ 3-11   ┆            ┆ 0NM00 ┆ 016        ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ 55    ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 2022-0 ┆ ZA16NQJR   ┆ ST800 ┆ 8001563222 ┆ ... ┆ 0          ┆ null     ┆ null       ┆ 0          │
# │ 3-11   ┆            ┆ 0NM00 ┆ 016        ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ 55    ┆            ┆     ┆            ┆          ┆            ┆            │
# │ 2022-0 ┆ 1050A084F9 ┆ TOSHI ┆ 1400051964 ┆ ... ┆ 0          ┆ null     ┆ null       ┆ 0          │
# │ 3-11   ┆ 7G         ┆ BA    ┆ 3136       ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ MG07A ┆            ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ CA14T ┆            ┆     ┆            ┆          ┆            ┆            │
# │        ┆            ┆ A     ┆            ┆     ┆            ┆          ┆            ┆            │
# └────────┴────────────┴───────┴────────────┴─────┴────────────┴──────────┴────────────┴────────────┘

# %%
df_failed_example = classification_target.filter(pl.col("serial_number") == "ZJV3BYAY")

# %%
df_failed_example
# Out:
# shape: (70, 40)
# ┌─────────┬────────────┬────────┬────────────┬─────┬────────────┬────────┬────────────┬────────────┐
# │ date    ┆ serial_num ┆ model  ┆ capacity_b ┆ ... ┆ smart_199_ ┆ failda ┆ Time_till_ ┆ failing_in │
# │ ---     ┆ ber        ┆ ---    ┆ ytes       ┆     ┆ raw        ┆ te     ┆ failure    ┆ 14days     │
# │ date    ┆ ---        ┆ str    ┆ ---        ┆     ┆ ---        ┆ ---    ┆ ---        ┆ ---        │
# │         ┆ str        ┆        ┆ i64        ┆     ┆ i64        ┆ date   ┆ duration[m ┆ i32        │
# │         ┆            ┆        ┆            ┆     ┆            ┆        ┆ s]         ┆            │
# ╞═════════╪════════════╪════════╪════════════╪═════╪════════════╪════════╪════════════╪════════════╡
# │ 2022-03 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 0ms        ┆ 1          │
# │ -11     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-03 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 6d         ┆ 1          │
# │ -05     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-01 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 56d        ┆ 0          │
# │ -14     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-01 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 42d        ┆ 0          │
# │ -28     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ ...     ┆ ...        ┆ ...    ┆ ...        ┆ ... ┆ ...        ┆ ...    ┆ ...        ┆ ...        │
# │ 2022-01 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 45d        ┆ 0          │
# │ -25     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-01 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 39d        ┆ 0          │
# │ -31     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-01 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 51d        ┆ 0          │
# │ -19     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# │ 2022-03 ┆ ZJV3BYAY   ┆ ST1200 ┆ 1200013862 ┆ ... ┆ 0          ┆ 2022-0 ┆ 3d         ┆ 1          │
# │ -08     ┆            ┆ 0NM000 ┆ 5024       ┆     ┆            ┆ 3-11   ┆            ┆            │
# │         ┆            ┆ 7      ┆            ┆     ┆            ┆        ┆            ┆            │
# └─────────┴────────────┴────────┴────────────┴─────┴────────────┴────────┴────────────┴────────────┘

# %%
target_savings=fe.search_faulty_drives(classification_target)
# Out:
# faulty drives saved to: Faulty_drives.csv

# %%
df_with_faildates = df_all.with_columns(pl.col("serial_number").map_dict(fail_dict).alias("faildate"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_with_faildates = df_all.with_columns(pl.col("serial_number").map_dict(fail_dict).alias("faildate"))
#
# NameError: name 'df_all' is not defined

# %%
df_with_faildates = df_all.with_columns(pl.col("serial_number").map_dict(fail_dict).alias("faildate"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_with_faildates = df_all.with_columns(pl.col("serial_number").map_dict(fail_dict).alias("faildate"))
#
# NameError: name 'fail_dict' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df_with_faildates.shape
# Out:
# (80357762, 38)

# %%
80357762 - 79781429
# Out:
# 576333

# %%
df_all = pl.read_csv('./data/2022_data_selected.parquet')
